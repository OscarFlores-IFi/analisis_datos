# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import ceil,sqrt
from sklearn.cluster import KMeans

def datos(archivo):
    ### extraer los datos ###
    datos = pd.read_csv(archivo,index_col=0) #
#    datos = np.array(datos) #equivalente a datos.values debido a que pandas esda basado en numpy. 
    datos = datos.values
    return (datos)

def cluster(datos, clusters):
    model = KMeans(n_clusters=clusters) # sci_kit_learn tiene un algoritmo de clustering en dónde solamente necesita especificarse el número de 
    model = model.fit(datos)
    return(model.cluster_centers_, model.predict(datos), model.inertia_)


    
close = datos("CloseAC.csv") #se sacan los datos de cierre y volumen para trabajar con ellos. 
volume = datos("VolumeAC.csv")

# %% [markdown]
# # Graficar Codos en volumen:

# %%
x = 10 ### modificar este para evaluar los datos con n centroides. 

centroides,grupos,total_inercia = [],[],[]
for i in range(1,x+1):
    k_values = cluster(volume, i)
    
    centroides.append(k_values[0]) #almacenar datos en listas. 
    grupos.append(k_values[1])
    total_inercia.append(k_values[2])

#%%
dif_inercia = [total_inercia[i] - total_inercia[i+1] for i in range(len(total_inercia)-1)] #grafica la diferencia entre cada una de las inercias. sirve para encontrar el "codo".
    
### se grafican las inercias globales (total_inercia) para conocer el 'codo'  
plt.plot(np.arange(1,len(total_inercia)+1),total_inercia)
plt.plot(np.arange(2,len(total_inercia)+1),dif_inercia)
plt.xlabel('iteraciones')
plt.ylabel('inercia global')
plt.grid()
plt.show()

# %% [markdown]
# **2 o 6 centroides**:
#
# Considerando la gráfica de inercias globales podemos apreciar que se presenta un codo cuando hay 5 centroides, así como también se presenta con 2 centroides.

# %% [markdown]
# # graficamos centroides en volumen:

# %%
### se grafican los centroides. 
cen = 2  ### modificar este para graficar n clusters. 
for i in range(len(centroides[cen - 1])):
    plt.subplot(ceil(sqrt(cen)),round(sqrt(cen)),i+1)
    plt.grid()
    plt.plot(centroides[cen - 1][i],label=('centroide %i'%i))
#plt.legend(loc='best')
plt.show()

# %%
### se grafican los centroides. 
cen = 3  ### modificar este para graficar n clusters. 
for i in range(len(centroides[cen - 1])):
    plt.subplot(ceil(sqrt(cen)),round(sqrt(cen)),i+1)
    plt.grid()
    plt.plot(centroides[cen - 1][i],label=('centroide %i'%i))
#plt.legend(loc='best')
plt.show()

# %%
### se grafican los centroides. 
cen = 5  ### modificar este para graficar n clusters. 
for i in range(len(centroides[cen - 1])):
    plt.subplot(ceil(sqrt(cen)),round(sqrt(cen)),i+1)
    plt.grid()
    plt.plot(centroides[cen - 1][i],label=('centroide %i'%i))
#plt.legend(loc='best')
plt.show()

# %%
### se grafican los centroides. 
cen = 6 ### modificar este para graficar n clusters. 
for i in range(len(centroides[cen - 1])):
    plt.subplot(ceil(sqrt(cen)),round(sqrt(cen)),i+1)
    plt.grid()
    plt.plot(centroides[cen - 1][i],label=('centroide %i'%i))
#plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Graficar Codos en cierre:

# %%
x = 10 ### modificar este para evaluar los datos con n centroides. 

centroides,grupos,total_inercia = [],[],[]
for i in range(1,x+1):
    k_values = cluster(close, i)
    
    centroides.append(k_values[0]) #almacenar datos en listas. 
    grupos.append(k_values[1])
    total_inercia.append(k_values[2])

#%%
dif_inercia = [total_inercia[i] - total_inercia[i+1] for i in range(len(total_inercia)-1)] #grafica la diferencia entre cada una de las inercias. sirve para encontrar el "codo".
    
### se grafican las inercias globales (total_inercia) para conocer el 'codo'  
plt.plot(np.arange(1,len(total_inercia)+1),total_inercia)
plt.plot(np.arange(2,len(total_inercia)+1),dif_inercia)
plt.xlabel('iteraciones')
plt.ylabel('inercia global')
plt.grid()
plt.show()

# %% [markdown]
# # Graficamos centroides en cierre

# %% [markdown]
# ### 4 centroides.

# %%
### se grafican los centroides. 
cen = 4  ### modificar este para graficar n clusters. 
for i in range(len(centroides[cen - 1])):
    plt.subplot(ceil(sqrt(cen)),round(sqrt(cen)),i+1)
    plt.grid()
    plt.plot(centroides[cen - 1][i],label=('centroide %i'%i))
#plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Probabilidades de Markov

# %% [markdown]
# ### Agrupamos.

# %%
### da nombre a cada una de los casos en las que se encuentran. Previo a hacer la tabla de probabilidades de Markov.

Cl,Vo = cluster(close,4)[1],cluster(volume,5)[1] #se decidió tomar 4 centroides para cierre y 2 para volumen.

Gr = [[Cl[i],Vo[i]] for i in range(len(Cl))] #se agrupa cada uno de los casos de cierre y volumen en una lista. 
Dic = [[i,j] for i in range(len(pd.value_counts(Cl))) for j in range(len(pd.value_counts(Vo)))] #se hace un diccionario de las combinaciones existentes en estos dos casos. 

n_g = np.zeros(len(Cl)) #lista en blanco dónde se escribirá cada combinación según sea el caso. 
for j in range(len(Dic)): 
    for i in range(len(Gr)):
        if Dic[j] == Gr[i]:
            n_g[i] = j

# %% [markdown]
# ### Imprimimos Tabla de frecuencias.

# %%
### Matriz de Probabilidades de Markov. 
Tam = len(Dic) #Tamaño de la matriz cuadrada.
N = np.zeros((Tam,Tam))         

for i in range(Tam):
    for j in range(Tam):
        for k in range(len(n_g)-1):
            if n_g[k+1]==j and n_g[k]==i:
                N[i][j] += 1

# %%
Markov = pd.DataFrame(data=N.T)
Markov.columns = [str(i) for i in Dic]
Markov.index = [str(i) for i in Dic]
Markov = Markov.style.background_gradient()
Markov
# Out:
# <style  type="text/css" >
#     #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col0 {
#             background-color:  #9cb9d9;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col1 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col2 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col3 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col4 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col5 {
#             background-color:  #ebe6f2;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col6 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col7 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col8 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col9 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col10 {
#             background-color:  #63a2cb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col11 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col12 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col13 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col14 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col15 {
#             background-color:  #a7bddb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col16 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col17 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col18 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow0_col19 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col0 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col1 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col2 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col3 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col4 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col5 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col6 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col7 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col8 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col9 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col10 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col11 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col12 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col13 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col14 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col15 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col16 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col17 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col18 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow1_col19 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col0 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col1 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col2 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col3 {
#             background-color:  #023858;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col4 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col5 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col6 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col7 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col8 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col9 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col10 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col11 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col12 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col13 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col14 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col15 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col16 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col17 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col18 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow2_col19 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col0 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col1 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col2 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col3 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col4 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col5 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col6 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col7 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col8 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col9 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col10 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col11 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col12 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col13 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col14 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186024acd04arow3_col15 {
#             background-color:  #fff7fb;
#         }    #T_c08bf01e_d400_11e8_9223_186

# %% [markdown]
# ## falta dividir la tabla de frecuencias entre la cantidad de elementos por columna para conseguir una tabla de probabilidades.

# %%
pd.DataFrame(data=N).to_csv('asdfg.csv')
